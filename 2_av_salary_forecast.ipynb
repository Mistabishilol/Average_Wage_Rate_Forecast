# %% [markdown]
# ### Импортируем библиотеки и данные

# %%
import sys
sys.path.append('.\\Functions\\')
# Основная функция для построения прогнозов.
from main import forecast_main
forecast_main()
# Out:
# Данные из базы планирования успешно загружены.
# Данные из базы сегментов успешно загружены.
# Данные по номинальной средней ЗП успешно загружены.
# Укажите отделения и сегменты для построения прогноза. Можно указать несколько отделений или сегментов через пробел.
# Для выбора всех отделений или сегментов используйте слово "all" или "все" без кавычек.
# Доступны следующие ТБ: 13 16 18 38 40 42 44 52 54 55 70 99
# Для выбранных ТБ доступны следующие ГОСБ: 54 1039 6991 8588 8621 8622 8623 8624 8625
# Для выбранных ТБ и ГОСБ доступны следующие сегменты: КСБ ММБ РГС_МВД РГС_МО РГС_МЧС РГС_Минздрав РГС_Росгвардия РГС_ФСИН РГС_ФССП РГС_малые_холдинги РГС_несиловой
# Для выбранных ТБ и ГОСБ доступны следующие типы: ЕПП реестр
# 07.09.2021 23:07:18 54_6991_КСБ_реестр работаю
# 07.09.2021 23:08:00 54_6991_КСБ_реестр ok
# 07.09.2021 23:08:00 54_6991_ММБ_реестр работаю
# 07.09.2021 23:08:41 54_6991_ММБ_реестр ok
# 07.09.2021 23:08:41 54_6991_РГС_МВД_реестр работаю
# 07.09.2021 23:09:19 54_6991_РГС_МВД_реестр ok
# 07.09.2021 23:09:19 54_6991_РГС_МО_реестр работаю
# 07.09.2021 23:10:01 54_6991_РГС_МО_реестр ok
# 07.09.2021 23:10:01 54_6991_РГС_МЧС_реестр работаю
# 07.09.2021 23:10:41 54_6991_РГС_МЧС_реестр ok
# 07.09.2021 23:10:41 54_6991_РГС_Минздрав_реестр работаю
# 07.09.2021 23:11:22 54_6991_РГС_Минздрав_реестр ok
# 07.09.2021 23:11:22 54_6991_РГС_Росгвардия_реестр работаю
# 07.09.2021 23:12:04 54_6991_РГС_Росгвардия_реестр ok
# 07.09.2021 23:12:04 54_6991_РГС_ФСИН_реестр работаю
# 07.09.2021 23:12:46 54_6991_РГС_ФСИН_реестр ok
# 07.09.2021 23:12:46 54_6991_РГС_ФССП_реестр работаю
# 07.09.2021 23:13:26 54_6991_РГС_ФССП_реестр ok
# 07.09.2021 23:13:26 54_6991_РГС_малые_холдинги_реестр работаю
# 07.09.2021 23:14:05 54_6991_РГС_малые_холдинги_реестр ok
# 07.09.2021 23:14:05 54_6991_РГС_несиловой_реестр работаю
# 07.09.2021 23:14:47 54_6991_РГС_несиловой_реестр ok
# Файл Results_07.09.2021 23-14-47.xlsx сохранён в папке ./Predictions/07.09.2021 23-07-18.
# Перезапустите ячейку для нового расчёта.
